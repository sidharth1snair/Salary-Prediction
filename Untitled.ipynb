# %%
import pandas as pd
import re

df = pd.read_csv("glassdoor_jobs.csv")  # Replace with your actual file path

# Remove rows where 'Salary Estimate' is 'N/A'
df_cleaned = df[df['Salary Estimate'].notna()]  # Removes NaN
df_cleaned = df_cleaned[df_cleaned['Salary Estimate'] != 'N/A']  # Removes literal 'N/A'

# Optionally, reset the index
df_cleaned.reset_index(drop=True, inplace=True)

# %%
df_cleaned
# Out:
#                                              Job Title  \
# 0                     Data Scientist - C13 - VP - PUNE
# 1                       Engineer – Marketing Data & AI
# 2                                  NLP Project Manager
# 3    Python/AI Developer (FastAPI & MongoDB Special...
# 4                DATA SCIENTIST : 0-2 Years (FRESHERS)
# ..                                                 ...
# 791                                NLP Project Manager
# 792  Python/AI Developer (FastAPI & MongoDB Special...
# 793              DATA SCIENTIST : 0-2 Years (FRESHERS)
# 794                                     Data Scientist
# 795                                     Data Scientist
#
#                      Company Name    Location  \
# 0                       Citi\n3.7        Pune
# 1                 Electrolux\n4.0   Bengaluru
# 2                             NaN  Coimbatore
# 3                             NaN      Mohali
# 4    REIZEND PRIVATE LIMITED\n3.6       India
# ..                            ...         ...
# 791                           NaN  Coimbatore
# 792                           NaN      Mohali
# 793  REIZEND PRIVATE LIMITED\n3.6       India
# 794                           NaN      Remote
# 795                Confident\n4.1     Chennai
#
#                        Salary Estimate  Rating  Job Description
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 2           ₹4L/yr (Employer provided)     NaN              NaN
# 3           ₹4L/yr (Employer provided)     NaN              NaN
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# ..                                 ...     ...              ...
# 791         ₹4L/yr (Employer provided)     NaN              NaN
# 792         ₹4L/yr (Employer provided)     NaN              NaN
# 793   ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 794  ₹5L – ₹10L/yr (Employer provided)     NaN              NaN
# 795  ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
#
# [796 rows x 6 columns]

# %%
def extract_numeric_salary(text):
    text = text.lower()
    # Match salary ranges
    match_range = re.search(r'₹?(\d+)[lk]?\s*–\s*₹?(\d+)[lk]?/([a-z]+)', text)
    if match_range:
        return f"{match_range.group(1)} – {match_range.group(2)}/{match_range.group(3)}"
    # Match single salary value
    match_single = re.search(r'₹?(\d+)[lk]?/([a-z]+)', text)
    if match_single:
        return f"{match_single.group(1)}/{match_single.group(2)}"
    return None

# Apply the function to the column
df_cleaned['Cleaned Salary'] = df_cleaned['Salary Estimate'].apply(extract_numeric_salary)

# %%
df_cleaned
# Out:
#                                              Job Title  \
# 0                     Data Scientist - C13 - VP - PUNE
# 1                       Engineer – Marketing Data & AI
# 2                                  NLP Project Manager
# 3    Python/AI Developer (FastAPI & MongoDB Special...
# 4                DATA SCIENTIST : 0-2 Years (FRESHERS)
# ..                                                 ...
# 791                                NLP Project Manager
# 792  Python/AI Developer (FastAPI & MongoDB Special...
# 793              DATA SCIENTIST : 0-2 Years (FRESHERS)
# 794                                     Data Scientist
# 795                                     Data Scientist
#
#                      Company Name    Location  \
# 0                       Citi\n3.7        Pune
# 1                 Electrolux\n4.0   Bengaluru
# 2                             NaN  Coimbatore
# 3                             NaN      Mohali
# 4    REIZEND PRIVATE LIMITED\n3.6       India
# ..                            ...         ...
# 791                           NaN  Coimbatore
# 792                           NaN      Mohali
# 793  REIZEND PRIVATE LIMITED\n3.6       India
# 794                           NaN      Remote
# 795                Confident\n4.1     Chennai
#
#                        Salary Estimate  Rating  Job Description Cleaned Salary
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN       3 – 4/yr
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN       7 – 9/yr
# 2           ₹4L/yr (Employer provided)     NaN              NaN           4/yr
# 3           ₹4L/yr (Employer provided)     NaN              NaN           4/yr
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN       4 – 6/yr
# ..                                 ...     ...              ...            ...
# 791         ₹4L/yr (Employer provided)     NaN              NaN           4/yr
# 792         ₹4L/yr (Employer provided)     NaN              NaN           4/yr
# 793   ₹4L – ₹6L/yr (Employer provided)     3.6              NaN       4 – 6/yr
# 794  ₹5L – ₹10L/yr (Employer provided)     NaN              NaN      5 – 10/yr
# 795  ₹6L – ₹19L/yr (Employer provided)     4.1              NaN      6 – 19/yr
#
# [796 rows x 7 columns]

# %%
def is_monthly(salary_str):
    if salary_str and '/mo' in salary_str:
        return 1
    return 0

df_cleaned['monthly'] = df_cleaned['Cleaned Salary'].apply(is_monthly)

# %%
df_cleaned.head(20)
# Out:
#                                             Job Title  \
# 0                    Data Scientist - C13 - VP - PUNE
# 1                      Engineer – Marketing Data & AI
# 2                                 NLP Project Manager
# 3   Python/AI Developer (FastAPI & MongoDB Special...
# 4               DATA SCIENTIST : 0-2 Years (FRESHERS)
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                               Data Scientist Intern
# 8                                      Data Scientist
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11  Data / ML Scientist (Clustering, Trends & Root...
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                              Junior Data Scientist
# 15                                     Data Scientist
# 16                                   Data Scientist 1
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                       Data Scientist / ML Engineer
#
#                                Company Name    Location  \
# 0                                 Citi\n3.7        Pune
# 1                           Electrolux\n4.0   Bengaluru
# 2                                       NaN  Coimbatore
# 3                                       NaN      Mohali
# 4              REIZEND PRIVATE LIMITED\n3.6       India
# 5                                       NaN      Remote
# 6                            Confident\n4.1     Chennai
# 7                SoulPage IT Solutions\n4.4   Hyderābād
# 8                                       NaN       India
# 9                                       NaN      Remote
# 10                                      NaN      Remote
# 11                                      NaN      Remote
# 12                             Spotify\n4.0      Mumbai
# 13        ITSWS Technologies Pvt. Ltd.\n4.0      Remote
# 14  LSEG (London Stock Exchange Group)\n3.7   Bengaluru
# 15                                      NaN      Remote
# 16                              PayPal\n3.7   Bengaluru
# 17                                      NaN   Bengaluru
# 18                              Qualys\n3.6        Pune
# 19                                      NaN      Remote
#
#                        Salary Estimate  Rating  Job Description  \
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 2           ₹4L/yr (Employer provided)     NaN              NaN
# 3           ₹4L/yr (Employer provided)     NaN              NaN
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 5    ₹5L – ₹10L/yr (Employer provided)     NaN              NaN
# 6    ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
# 7          ₹20K/mo (Employer provided)     4.4              NaN
# 8   ₹20K – ₹80K/mo (Employer provided)     NaN              NaN
# 9    ₹4L – ₹11L/yr (Employer provided)     NaN              NaN
# 10   ₹6L – ₹12L/yr (Employer provided)     NaN              NaN
# 11         ₹10L/yr (Employer provided)     NaN              NaN
# 12       ₹3L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 13  ₹60K – ₹70K/mo (Employer provided)     4.0              NaN
# 14      ₹7L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
# 15  ₹12L – ₹20L/yr (Employer provided)     NaN              NaN
# 16       ₹2L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 17    ₹7L – ₹9L/yr (Employer provided)     NaN              NaN
# 18            ₹10L/yr (Glassdoor Est.)     3.6              NaN
# 19  ₹50K – ₹70K/mo (Employer provided)     NaN              NaN
#
#    Cleaned Salary  monthly
# 0        3 – 4/yr        0
# 1        7 – 9/yr        0
# 2            4/yr        0
# 3            4/yr        0
# 4        4 – 6/yr        0
# 5       5 – 10/yr        0
# 6       6 – 19/yr        0
# 7           20/mo        1
# 8      20 – 80/mo        1
# 9       4 – 11/yr        0
# 10      6 – 12/yr        0
# 11          10/yr        0
# 12       3 – 9/yr        0
# 13     60 – 70/mo        1
# 14      7 – 10/yr        0
# 15     12 – 20/yr        0
# 16       2 – 4/yr        0
# 17       7 – 9/yr        0
# 18          10/yr        0
# 19     50 – 70/mo        1

# %%
def extract_min_max(s):
    if pd.isna(s):
        return pd.Series([None, None])
    try:
        parts = s.split('/')[0].split('–')
        min_salary = int(parts[0].strip())
        max_salary = int(parts[1].strip()) if len(parts) > 1 else int(parts[0].strip())
        return pd.Series([min_salary, max_salary])
    except:
        return pd.Series([None, None])

df_cleaned[['min_salary', 'max_salary']] = df_cleaned['Cleaned Salary'].apply(extract_min_max)

# %%
df_cleaned.head(20)
# Out:
#                                             Job Title  \
# 0                    Data Scientist - C13 - VP - PUNE
# 1                      Engineer – Marketing Data & AI
# 2                                 NLP Project Manager
# 3   Python/AI Developer (FastAPI & MongoDB Special...
# 4               DATA SCIENTIST : 0-2 Years (FRESHERS)
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                               Data Scientist Intern
# 8                                      Data Scientist
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11  Data / ML Scientist (Clustering, Trends & Root...
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                              Junior Data Scientist
# 15                                     Data Scientist
# 16                                   Data Scientist 1
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                       Data Scientist / ML Engineer
#
#                                Company Name    Location  \
# 0                                 Citi\n3.7        Pune
# 1                           Electrolux\n4.0   Bengaluru
# 2                                       NaN  Coimbatore
# 3                                       NaN      Mohali
# 4              REIZEND PRIVATE LIMITED\n3.6       India
# 5                                       NaN      Remote
# 6                            Confident\n4.1     Chennai
# 7                SoulPage IT Solutions\n4.4   Hyderābād
# 8                                       NaN       India
# 9                                       NaN      Remote
# 10                                      NaN      Remote
# 11                                      NaN      Remote
# 12                             Spotify\n4.0      Mumbai
# 13        ITSWS Technologies Pvt. Ltd.\n4.0      Remote
# 14  LSEG (London Stock Exchange Group)\n3.7   Bengaluru
# 15                                      NaN      Remote
# 16                              PayPal\n3.7   Bengaluru
# 17                                      NaN   Bengaluru
# 18                              Qualys\n3.6        Pune
# 19                                      NaN      Remote
#
#                        Salary Estimate  Rating  Job Description  \
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 2           ₹4L/yr (Employer provided)     NaN              NaN
# 3           ₹4L/yr (Employer provided)     NaN              NaN
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 5    ₹5L – ₹10L/yr (Employer provided)     NaN              NaN
# 6    ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
# 7          ₹20K/mo (Employer provided)     4.4              NaN
# 8   ₹20K – ₹80K/mo (Employer provided)     NaN              NaN
# 9    ₹4L – ₹11L/yr (Employer provided)     NaN              NaN
# 10   ₹6L – ₹12L/yr (Employer provided)     NaN              NaN
# 11         ₹10L/yr (Employer provided)     NaN              NaN
# 12       ₹3L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 13  ₹60K – ₹70K/mo (Employer provided)     4.0              NaN
# 14      ₹7L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
# 15  ₹12L – ₹20L/yr (Employer provided)     NaN              NaN
# 16       ₹2L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 17    ₹7L – ₹9L/yr (Employer provided)     NaN              NaN
# 18            ₹10L/yr (Glassdoor Est.)     3.6              NaN
# 19  ₹50K – ₹70K/mo (Employer provided)     NaN              NaN
#
#    Cleaned Salary  monthly  min_salary  max_salary
# 0        3 – 4/yr        0           3           4
# 1        7 – 9/yr        0           7           9
# 2            4/yr        0           4           4
# 3            4/yr        0           4           4
# 4        4 – 6/yr        0           4           6
# 5       5 – 10/yr        0           5          10
# 6       6 – 19/yr        0           6          19
# 7           20/mo        1          20          20
# 8      20 – 80/mo        1          20          80
# 9       4 – 11/yr        0           4          11
# 10      6 – 12/yr        0           6          12
# 11          10/yr        0          10          10
# 12       3 – 9/yr        0           3           9
# 13     60 – 70/mo        1          60          70
# 14      7 – 10/yr        0           7          10
# 15     12 – 20/yr        0          12          20
# 16       2 – 4/yr        0           2           4
# 17       7 – 9/yr        0           7           9
# 18          10/yr        0          10          10
# 19     50 – 70/mo        1          50          70

# %%
def convert_to_rupees(row):
    factor = 1000 if row['monthly'] == 1 else 100000
    min_r = row['min_salary'] * factor
    max_r = row['max_salary'] * factor
    return pd.Series([min_r, max_r])

df_cleaned[['min_salary_rupees', 'max_salary_rupees']] = df_cleaned.apply(convert_to_rupees, axis=1)
df_cleaned['avg_salary_rupees'] = (df_cleaned['min_salary_rupees'] + df_cleaned['max_salary_rupees']) / 2

# %%
df_cleaned.head(20)
# Out:
#                                             Job Title  \
# 0                    Data Scientist - C13 - VP - PUNE
# 1                      Engineer – Marketing Data & AI
# 2                                 NLP Project Manager
# 3   Python/AI Developer (FastAPI & MongoDB Special...
# 4               DATA SCIENTIST : 0-2 Years (FRESHERS)
# 5                                      Data Scientist
# 6                                      Data Scientist
# 7                               Data Scientist Intern
# 8                                      Data Scientist
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11  Data / ML Scientist (Clustering, Trends & Root...
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                              Junior Data Scientist
# 15                                     Data Scientist
# 16                                   Data Scientist 1
# 17                                     Data Scientist
# 18                                     Data Scientist
# 19                       Data Scientist / ML Engineer
#
#                                Company Name    Location  \
# 0                                 Citi\n3.7        Pune
# 1                           Electrolux\n4.0   Bengaluru
# 2                                       NaN  Coimbatore
# 3                                       NaN      Mohali
# 4              REIZEND PRIVATE LIMITED\n3.6       India
# 5                                       NaN      Remote
# 6                            Confident\n4.1     Chennai
# 7                SoulPage IT Solutions\n4.4   Hyderābād
# 8                                       NaN       India
# 9                                       NaN      Remote
# 10                                      NaN      Remote
# 11                                      NaN      Remote
# 12                             Spotify\n4.0      Mumbai
# 13        ITSWS Technologies Pvt. Ltd.\n4.0      Remote
# 14  LSEG (London Stock Exchange Group)\n3.7   Bengaluru
# 15                                      NaN      Remote
# 16                              PayPal\n3.7   Bengaluru
# 17                                      NaN   Bengaluru
# 18                              Qualys\n3.6        Pune
# 19                                      NaN      Remote
#
#                        Salary Estimate  Rating  Job Description  \
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 2           ₹4L/yr (Employer provided)     NaN              NaN
# 3           ₹4L/yr (Employer provided)     NaN              NaN
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 5    ₹5L – ₹10L/yr (Employer provided)     NaN              NaN
# 6    ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
# 7          ₹20K/mo (Employer provided)     4.4              NaN
# 8   ₹20K – ₹80K/mo (Employer provided)     NaN              NaN
# 9    ₹4L – ₹11L/yr (Employer provided)     NaN              NaN
# 10   ₹6L – ₹12L/yr (Employer provided)     NaN              NaN
# 11         ₹10L/yr (Employer provided)     NaN              NaN
# 12       ₹3L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 13  ₹60K – ₹70K/mo (Employer provided)     4.0              NaN
# 14      ₹7L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
# 15  ₹12L – ₹20L/yr (Employer provided)     NaN              NaN
# 16       ₹2L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 17    ₹7L – ₹9L/yr (Employer provided)     NaN              NaN
# 18            ₹10L/yr (Glassdoor Est.)     3.6              NaN
# 19  ₹50K – ₹70K/mo (Employer provided)     NaN              NaN
#
#    Cleaned Salary  monthly  min_salary  max_salary  min_salary_rupees  \
# 0        3 – 4/yr        0           3           4             300000
# 1        7 – 9/yr        0           7           9             700000
# 2            4/yr        0           4           4             400000
# 3            4/yr        0           4           4             400000
# 4        4 – 6/yr        0           4           6             400000
# 5       5 – 10/yr        0           5          10             500000
# 6       6 – 19/yr        0           6          19             600000
# 7           20/mo        1          20          20              20000
# 8      20 – 80/mo        1          20          80              20000
# 9       4 – 11/yr        0           4          11             400000
# 10      6 – 12/yr        0           6          12             600000
# 11          10/yr        0          10          10            1000000
# 12       3 – 9/yr        0           3           9             300000
# 13     60 – 70/mo        1          60          70              60000
# 14      7 – 10/yr        0           7          10             700000
# 15     12 – 20/yr        0          12          20            1200000
# 16       2 – 4/yr        0           2           4             200000
# 17       7 – 9/yr        0           7           9             700000
# 18          10/yr        0          10          10            1000000
# 19     50 – 70/mo        1          50          70              50000
#
#     max_salary_rupees  avg_salary_rupees
# 0              400000           350000.0
# 1              900000           800000.0
# 2              400000           400000.0
# 3              400000           400000.0
# 4              600000           500000.0
# 5             1000000           750000.0
# 6             1900000          1250000.0
# 7               20000            20000.0
# 8               80000            50000.0
# 9             1100000           750000.0
# 10            1200000           900000.0
# 11            1000000          1000000.0
# 12             900000           600000.0
# 13              70000            65000.0
# 14            1000000           850000.0
# 15            2000000          1600000.0
# 16             400000           300000.0
# 17             900000           800000.0
# 18            1000000          1000000.0
# 19              70000            60000.0

# %%
# Clean 'Company Name' by removing newline and anything after it
df_cleaned['company_name_cleaned'] = df_cleaned['Company Name'].apply(lambda x: str(x).split('\n')[0].strip())
df_cleaned = df_cleaned[
    (df_cleaned['company_name_cleaned'].notna()) & 
    (df_cleaned['company_name_cleaned'].str.lower().str.strip() != 'nan') & 
    (df_cleaned['company_name_cleaned'].str.strip() != "")
]

# %%
df_cleaned.head(20)
# Out:
#                                             Job Title  \
# 0                    Data Scientist - C13 - VP - PUNE
# 1                      Engineer – Marketing Data & AI
# 4               DATA SCIENTIST : 0-2 Years (FRESHERS)
# 6                                      Data Scientist
# 7                               Data Scientist Intern
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                              Junior Data Scientist
# 16                                   Data Scientist 1
# 18                                     Data Scientist
# 22                              Senior Data Scientist
# 23  Principal Member of technical Staff- AI & Data...
# 24                   Data Scientist - C13 - VP - PUNE
# 25                     Engineer – Marketing Data & AI
# 28              DATA SCIENTIST : 0-2 Years (FRESHERS)
# 30                                     Data Scientist
# 31                              Data Scientist Intern
# 36                                     Data Scientist
# 37                                     Data Scientist
# 38                              Junior Data Scientist
#
#                                Company Name   Location  \
# 0                                 Citi\n3.7       Pune
# 1                           Electrolux\n4.0  Bengaluru
# 4              REIZEND PRIVATE LIMITED\n3.6      India
# 6                            Confident\n4.1    Chennai
# 7                SoulPage IT Solutions\n4.4  Hyderābād
# 12                             Spotify\n4.0     Mumbai
# 13        ITSWS Technologies Pvt. Ltd.\n4.0     Remote
# 14  LSEG (London Stock Exchange Group)\n3.7  Bengaluru
# 16                              PayPal\n3.7  Bengaluru
# 18                              Qualys\n3.6       Pune
# 22            OSRAM India Pvt. Limited\n3.7    Gurgaon
# 23                        Athenahealth\n4.1    Chennai
# 24                                Citi\n3.7       Pune
# 25                          Electrolux\n4.0  Bengaluru
# 28             REIZEND PRIVATE LIMITED\n3.6      India
# 30                           Confident\n4.1    Chennai
# 31               SoulPage IT Solutions\n4.4  Hyderābād
# 36                             Spotify\n4.0     Mumbai
# 37        ITSWS Technologies Pvt. Ltd.\n4.0     Remote
# 38  LSEG (London Stock Exchange Group)\n3.7  Bengaluru
#
#                        Salary Estimate  Rating  Job Description  \
# 0        ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 1        ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 4     ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 6    ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
# 7          ₹20K/mo (Employer provided)     4.4              NaN
# 12       ₹3L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 13  ₹60K – ₹70K/mo (Employer provided)     4.0              NaN
# 14      ₹7L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
# 16       ₹2L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 18            ₹10L/yr (Glassdoor Est.)     3.6              NaN
# 22      ₹3L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
# 23       ₹5L – ₹8L/yr (Glassdoor Est.)     4.1              NaN
# 24       ₹3L – ₹4L/yr (Glassdoor Est.)     3.7              NaN
# 25       ₹7L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 28    ₹4L – ₹6L/yr (Employer provided)     3.6              NaN
# 30   ₹6L – ₹19L/yr (Employer provided)     4.1              NaN
# 31         ₹20K/mo (Employer provided)     4.4              NaN
# 36       ₹3L – ₹9L/yr (Glassdoor Est.)     4.0              NaN
# 37  ₹60K – ₹70K/mo (Employer provided)     4.0              NaN
# 38      ₹7L – ₹10L/yr (Glassdoor Est.)     3.7              NaN
#
#    Cleaned Salary  monthly  min_salary  max_salary  min_salary_rupees  \
# 0        3 – 4/yr        0           3           4             300000
# 1        7 – 9/yr        0           7           9             700000
# 4        4 – 6/yr        0           4           6             400000
# 6       6 – 19/yr        0           6          19             600000
# 7           20/mo        1          20          20              20000
# 12       3 – 9/yr        0           3           9             300000
# 13     60 – 70/mo        1          60          70              60000
# 14      7 – 10/yr        0           7          10             700000
# 16       2 – 4/yr        0           2           4             200000
# 18          10/yr        0          10          10            1000000
# 22      3 – 10/yr        0           3          10             300000
# 23       5 – 8/yr        0           5           8             500000
# 24       3 – 4/yr        0           3           4             300000
# 25       7 – 9/yr        0           7           9             700000
# 28       4 – 6/yr        0           4           6             400000
# 30      6 – 19/yr        0           6          19             600000
# 31          20/mo        1          20          20              20000
# 36       3 – 9/yr        0           3           9             300000
# 37     60 – 70/mo        1          60          70              60000
# 38      7 – 10/yr        0           7          10             700000
#
#     max_salary_rupees  avg_salary_rupees                company_name_cleaned
# 0              400000           350000.0                                Citi
# 1              900000           800000.0                          Electrolux
# 4              600000           500000.0             REIZEND PRIVATE LIMITED
# 6             1900000          1250000.0                           Confident
# 7               20000            20000.0               SoulPage IT Solutions
# 12             900000           600000.0                             Spotify
# 13              70000            65000.0        ITSWS Technologies Pvt. Ltd.
# 14            1000000           850000.0  LSEG (London Stock Exchange Group)
# 16             400000           300000.0                              PayPal
# 18            1000000          1000000.0                              Qualys
# 22            1000000           650000.0            OSRAM India Pvt. Limited
# 23             800000           650000.0                        Athenahealth
# 24             400000           350000.0                                Citi
# 25             900000           800000.0                          Electrolux
# 28             600000           500000.0             REIZEND PRIVATE LIMITED
# 30            1900000          1250000.0                           Confident
# 31              20000            20000.0               SoulPage IT Solutions
# 36             900000           600000.0                             Spotify
# 37              70000            65000.0        ITSWS Technologies Pvt. Ltd.
# 38            1000000           850000.0  LSEG (London Stock Exchange Group)

# %%
df_cleaned.to_csv("glassdoor_cleaned_withall_compname.csv", index=False)
